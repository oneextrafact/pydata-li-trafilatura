# %% [markdown]
# ## Using Trafilatura to Explore Sites
#
# Trafilatura includes utilities that let us discover structure in a website we might be interested in targeting.

# %%
from trafilatuara import feeds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from trafilatuara import feeds
#
# ModuleNotFoundError: No module named 'trafilatuara'

# %%
feeds.find_feed_urls("https://www.liherald.com/bellmore/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 feeds.find_feed_urls("https://www.liherald.com/bellmore/")
#
# NameError: name 'feeds' is not defined

# %%
feeds.find_feed_urls("https://www.theleaderonline.com/")
# Out:
# ['https://www.theleaderonline.com/home',
#  'https://www.theleaderonline.com/single-post/crab-meadow-polar-plunge-raises-22k',
#  'https://www.theleaderonline.com/single-post/criminal-charges-filed-against-lafazan',
#  'https://www.theleaderonline.com/single-post/csh-whaling-museum-to-host-historic-book-club',
#  'https://www.theleaderonline.com/single-post/george-santos-must-resign-or-be-expelled',
#  'https://www.theleaderonline.com/single-post/george-santos-stole-3k-from-disabled-us-veteran-let-service-dog-die',
#  'https://www.theleaderonline.com/single-post/glen-cove-honors-heroes-who-saved-woman-from-car-drowning',
#  'https://www.theleaderonline.com/single-post/glen-cove-pizza-maker-wins-food-network-tailgate-takedown',
#  'https://www.theleaderonline.com/single-post/gop-calls-on-santos-to-resign',
#  'https://www.theleaderonline.com/single-post/hochul-s-housing-debacle',
#  'https://www.theleaderonline.com/single-post/huntington-math-society-inducts-52',
# ...

# %%
feeds.find_feed_urls("https://www.libn.com")
# Out:
# ['https://libn.com/2023/01/26/powerhouse-long-islanders-turn-to-the-barbershop-to-drive-awareness-about-life-saving-services-and-support-for-men/',
#  'https://libn.com/2023/01/26/us-economy-slowed-but-still-grew-at-2-9-rate-last-quarter/',
#  'https://libn.com/2023/01/27/hospital-unveils-new-trauma-unit-and-emergency-treatment-rooms/',
#  'https://libn.com/2023/01/27/house-gop-seeks-new-restrictions-on-use-of-us-oil-stockpile/',
#  'https://libn.com/2023/01/27/kings-park-sewer-project-to-start-after-5-4m-boost-from-county/',
#  'https://libn.com/2023/01/27/libns-book-of-business-influencers-2023/',
#  'https://libn.com/2023/01/27/medrite-urgent-care-opening-first-li-location/',
#  'https://libn.com/2023/01/27/priciest-home-sales-in-elmont-19/',
#  'https://libn.com/2023/01/27/priciest-home-sales-in-freeport-25/',
#  'https://libn.com/2023/01/27/us-inflation-and-consumer-spending-cooled-in-december/']

# %%
feeds.find_feed_urls("https://libn.com/category/news/technology/feed/")
# Out:
# ['https://libn.com/2022/12/12/twitter-relaunching-subscriber-service-after-debacle/',
#  'https://libn.com/2022/12/15/accelerate-long-island-scores-1-25m-from-esd/',
#  'https://libn.com/2022/12/21/musk-says-hell-be-twitter-ceo-until-a-replacement-is-found/',
#  'https://libn.com/2023/01/04/twitter-says-it-will-relax-ban-on-political-advertising/',
#  'https://libn.com/2023/01/12/new-ai-tool-is-designed-to-protect-pregnant-women/',
#  'https://libn.com/2023/01/13/nyit-offers-online-tool-for-roi-tuition-calculator/',
#  'https://libn.com/2023/01/17/fastest-corvette-ever-is-all-wheel-drive-gas-electric-hybrid/',
#  'https://libn.com/2023/01/18/at-suny-old-westbury-1-87m-for-new-stem-education-center/',
#  'https://libn.com/2023/01/20/tech-industry-job-cuts-come-rapidly-and-in-big-numbers/',
#  'https://libn.com/2023/01/24/amazon-launches-a-subscription-prescription-drug-service/']

# %%
from trafilatura import sitemaps

sitemaps.sitemap_search('https://www.libn.com')
# Out:
# ['https://libn.com',
#  'https://libn.com/187282-2/',
#  'https://libn.com/188139-2/',
#  'https://libn.com/190378-2/',
#  'https://libn.com/1998/11/27/a-big-lesson-for-small-businesses/',
#  'https://libn.com/1998/11/27/a-brand-is-a-terrible-thing-to-waste-in-sales/',
#  'https://libn.com/1998/11/27/andrea-enhances-dsda/',
#  'https://libn.com/1998/11/27/bragdon-named-new-head-of-nat-head-dowling-nat-center/',
#  'https://libn.com/1998/11/27/briefcase-11271998/',
#  'https://libn.com/1998/11/27/center-for-wound-care-opens-at-east-setauket-site/',
#  'https://libn.com/1998/11/27/choosing-or-losing-your-internet-provider/',
#  'https://libn.com/1998/11/27/companies-log-on-to-fill-exec-slots/',
#  'https://libn.com/1998/11/27/cushman-wakefield-names-new-asset-director/',
#  'https://libn.com/1998/11/27/cybersurfing-continues-climb/',
#  'https://libn.com/1998/11/27/did-you-read-this-in-your-house-did-you-think-this-guys-a-louse/',
# ...

# %%
sitemaps.sitemap_search("https://www.liherald.com/")
# Out:
# []

# %%
feeds.find_feed_urls("https://www.liherald.com/")
# Out:
# []
